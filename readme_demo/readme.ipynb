# %% [markdown]
# # README Demo
#
# - Ubuntu 22.04
# - Python 3.10.12
# - Cannon EOS R100
# - Keigan Motor KM-1S

# %% [markdown]
# ## Befere Starting
#
# Setup all the hardware and adjust the settings as necessary.
#
# - Serup tripod and turntable
# - Connect all devices and power on
# - Configure network settings
# - Adjust the camera focus

# %%
import os
import json
import time
from pprint import pprint

import serial.tools.list_ports
import pandas as pd

from importers import JumpDir
with JumpDir(os.path.join('..', 'src'), os.getcwd()):
	__import__('ugokukun')
from ugokukun.ugoku_kun import UgokuKun
from ugokukun.ugoku_helpers import UgokuHelpers

# %% [markdown]
# ## Set up directories

# %%
config_dir = os.path.join(os.getcwd(), 'conf')
output_dir = os.path.join(os.getcwd(), 'dump')

# %% [markdown]
# # Search Serial Port and edit `device_list.json`
#
# **NOTE**: Keigan Motor comes with a Type-C USB cable, but that is only for power. You need to use a Micro USB cable to use USB Serial.
#
# For Linux:
#
# If sudo privileges are required, try adding user to the `dialout` group.
#
# [https://askubuntu.com/questions/133235/how-do-i-allow-non-root-access-to-ttyusb0](https://askubuntu.com/questions/133235/how-do-i-allow-non-root-access-to-ttyusb0)
#
# ```bash
# sudo adduser $USER dialout
# ```

# %%
ports = serial.tools.list_ports.comports()
for port, desc, hwid in ports:
    print(f"{port}: {desc} [{hwid}]")
print("# of ports:", len(ports))
# Out:
# /dev/ttyUSB0: FT230X Basic UART - FT230X Basic UART [USB VID:PID=0403:6015 SER=DM00KFY6 LOCATION=3-4]
# # of ports: 1

# %% [markdown]
# Select the port for your turntable.

# %%
# Set your port here
# port = '/dev/ttyUSB0'
port = ports[0].device

# %% [markdown]
# Open `device_list.json` and manually set port if necessary.
#
# If it seems OK, skip to [next step](#instantiate-ugokukun).

# %%
devices_json = UgokuHelpers.import_json(
	os.path.join(config_dir, 'device_list.json')
)
pprint(devices_json)
# Out:
# {'cannon': {'camera_0': '192.168.11.152:8080'},
#  'keigan': {'turntable_0': '/dev/ttyUSB0'}}

# %%
turntable_id_to_reset = "turntable_0" # Choose your turntable
devices_json["keigan"][turntable_id_to_reset] = port
pprint(devices_json)
# Out:
# {'cannon': {'camera_0': '192.168.11.152:8080'},
#  'keigan': {'turntable_0': '/dev/ttyUSB0'}}

# %% [markdown]
# Write out `device_list.json`.

# %%
with open(os.path.join(config_dir, 'device_list.json'), 'w') as f:
    json.dump(devices_json, f, indent=4)

# %% [markdown]
# ## Instantiate UgokuKun
#
# First read `camera_setup.csv` to set up the camera. Later, we will load the tasks csv file.

# %%
now = time.strftime("%Y%m%d_%H%M%S")
log_fname = os.path.join(output_dir, f"{now}.log")
log_fname

session = UgokuKun(
	task_csv_path    = os.path.join(config_dir, 'camera_setup.csv'),
	device_json_path = os.path.join(config_dir, 'device_list.json'),
	log_path         = log_fname
)
# Out:
# NOTICE: attempting to kill any process using the serial port: /dev/ttyUSB0
#   - shell error:
#   - Connecting to motor...
# Precheck error: No data received
# 	attemping to reconnect...
# Initialized Keigan motor at:
#   - /dev/ttyUSB0
# API URL: http://192.168.11.152:8080/ccapi
#   - Request success: 200
#   - Connection established
# API URL: http://192.168.11.152:8080/ccapi/ver100/deviceinformation
#   - Request success: 200
#   - Acquired device information
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
# API URL: http://192.168.11.152:8080/ccapi/ver100/functions/autopoweroff
#   - Request success: 200
#   - Auto power off is disabled: {"value":"disable"}
# Connected to Cannon camera:
#   - Canon EOS R100
#   - 192.168.11.152:8080
# ...reconnecting...
# Probably connected to Keigan motor (not sure until it's used).
#    If this is not the first connection to the motor, it can get stuck in an endless loop in:
#    - pykeigan.usbcontroller.USBController.reconnect()
#    If the connection works fine, you can just ignore it.

# %% [markdown]
# ### Check devices

# %%
print(session.cannon_cameras)
print(session.keigan_motors)
# Out:
# {'camera_0': '192.168.11.152:8080'}
# {'turntable_0': '/dev/ttyUSB0'}

# %% [markdown]
# ### Check task csv

# %%
session.csv_df
# Out:
#              task_id  wait_time    target             action   param  payload
# 0       set_aperture          3  camera_0           aperture     f10      NaN
# 1       ser_exposure          3  camera_0           exposure  -0_2/3      NaN
# 2       set_col_temp          3  camera_0  color_temperature    7200      NaN
# 3            set_iso          3  camera_0                iso    auto      NaN
# 4  set_shutter_speed          3  camera_0      shutter_speed      5"      NaN

# %% [markdown]
# ## Setup camera
#
# After checking that the task csv is correct, we can setup the cameras.
#
# - `UgokuKun.run()` will run the tasks normally.
# - `UgokuKun.test_run()` will run the tasks ignoring the wait times

# %%
session.test_run()
# Out:
# Executing task id: set_aperture , action: aperture
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/av
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - Exposure set to: f10
# Executing task id: ser_exposure , action: exposure
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/exposure
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - Exposure set to: -0_2/3
# Executing task id: set_col_temp , action: color_temperature
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/colortemperature
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - Color temperature set to: 7200
# Executing task id: set_iso , action: iso
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/iso
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - ISO set to: auto
# Executing task id: set_shutter_speed , action: shutter_speed
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/tv
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - Shutter speed set to: 5"

# %% [markdown]
# After running above, check the images taken by the camera.
#
# If it needs reconfiguration, edit the `camera_setup.csv` and reload the tasks csv file.

# %%
session.load_task_csv(os.path.join(config_dir, 'camera_setup.csv'))
# Out:
#              task_id  wait_time    target             action   param  payload
# 0       set_aperture          3  camera_0           aperture     f10      NaN
# 1       ser_exposure          3  camera_0           exposure  -0_2/3      NaN
# 2       set_col_temp          3  camera_0  color_temperature    7200      NaN
# 3            set_iso          3  camera_0                iso    auto      NaN
# 4  set_shutter_speed          3  camera_0      shutter_speed      5"      NaN

# %% [markdown]
# If the loaded tasks csv file is correct, re-run `UgokuKun.test_run()`.

# %%
session.test_run()
# Out:
# Executing task id: set_aperture , action: aperture
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/av
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - Exposure set to: f10
# Executing task id: ser_exposure , action: exposure
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/exposure
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - Exposure set to: -0_2/3
# Executing task id: set_col_temp , action: color_temperature
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/colortemperature
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - Color temperature set to: 7200
# Executing task id: set_iso , action: iso
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/iso
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - ISO set to: auto
# Executing task id: set_shutter_speed , action: shutter_speed
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/tv
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
#   - Current shooting parameters: {"shootingmodedial":{"value":"m"},"av":{"value":"f10","ability":["f2.8","f3.2","f3.5","f4.0","f4.5","f5.0","f5.6","f6.3","f7.1","f8.0","f9.0","f10","f11","f13","f14","f16","f18","f20","f22"]},"tv":{"value":"5\"","ability":["bulb","30\"","25\"","20\"","15\"","13\"","10\"","8\"","6\"","5\"","4\"","3\"2","2\"5","2\"","1\"6","1\"3","1\"","0\"8","0\"6","0\"5","0\"4","0\"3","1\/4","1\/5","1\/6","1\/8","1\/10","1\/13","1\/15","1\/20","1\/25","1\/30","1\/40","1\/50","1\/60","1\/80","1\/100","1\/125","1\/160","1\/200","1\/250","1\/320","1\/400","1\/500","1\/640","1\/800","1\/1000","1\/1250","1\/1600","1\/2000","1\/2500","1\/3200","1\/4000"]},"iso":{"value":"auto","ability":["auto","100","125","160","200","250","320","400","500","640","800","1000","1250","1600","2000","2500","3200","4000","5000","6400","8000","10000","12800"]},"exposure":{"value":"-0_2\/3","ability":["-3.0","-2_2\/3","-2_1\/3","-2.0","-1_2\/3","-1_1\/3","-1.0","-0_2\/3","-0_1\/3","+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0","+2_1\/3","+2_2\/3","+3.0"]},"wb":{"value":"auto","ability":["auto","awbwhite","daylight","shade","cloudy","tungsten","whitefluorescent","flash","custom","colortemp"]},"colortemperature":{"value":7200,"ability":{"min":2500,"max":10000,"step":100}},"afoperation":{"value":"manual"},"afmethod":{"value":"face+tracking","ability":["face+tracking","spot","1point","zone"]},"stillimagequality":{"value":{"raw":"none","jpeg":"large_fine"},"ability":{"raw":["none","raw","craw"],"jpeg":["none","large_fine","large_normal","medium_fine","medium_normal","small1_fine","small1_normal","small2"]}},"stillimageaspectratio":{"value":"3:2","ability":["3:2","4:3","16:9","1:1"]},"flash":{"value":"on","ability":["on","off"]},"metering":{"value":"evaluative","ability":["evaluative","partial","spot","center_weighted_average"]},"drive":{"value":"single","ability":["single","continuous","self_10sec","self_2sec","self_continuous"]},"aeb":{"value":"+0.0","ability":["+0.0","+0_1\/3","+0_2\/3","+1.0","+1_1\/3","+1_2\/3","+2.0"]},"wbshift":{"value":{"ba":0,"mg":0},"ability":{"ba":{"min":-9,"max":9,"step":1},"mg":{"min":-9,"max":9,"step":1}}},"wbbracket":{"value":"0","ability":["0","ba1","ba2","ba3","mg1","mg2","mg3"]},"colorspace":{"value":"srgb","ability":["srgb","adobe_rgb"]},"picturestyle":{"value":"auto","ability":["auto","standard","portrait","landscape","finedetail","neutral","faithful","monochrome","userdef1","userdef2","userdef3"]},"picturestyle_auto":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_standard":{"value":{"sharpness_strength":4,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_portrait":{"value":{"sharpness_strength":3,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1},"sharpness_threshold":{"min":1,"max":5,"step":1},"contrast":{"min":-4,"max":4,"step":1},"saturation":{"min":-4,"max":4,"step":1},"colortone":{"min":-4,"max":4,"step":1}}},"picturestyle_landscape":{"value":{"sharpness_strength":5,"sharpness_fineness":2,"sharpness_threshold":4,"contrast":0,"saturation":0,"colortone":0},"ability":{"sharpness_strength":{"min":0,"max":7,"step":1},"sharpness_fineness":{"min":1,"max":5,"step":1} ...
#   - Shutter speed set to: 5"

# %% [markdown]
# Repeat this process until the camera is set up correctly.

# %% [markdown]
# ## Run the tasks

# %% [markdown]
# In order to run the actual tasks, load the appropriate tasks csv file and run `UgokuKun.run()`.

# %%
actual_task = os.path.join(config_dir, 'as_you_wish.csv')
session.load_task_csv(actual_task)
# Out:
#          task_id  wait_time       target   action  param  payload
# 0      shutter_0          3     camera_0  shutter  False      NaN
# 1           cw_0          3  turntable_0       cw      5      NaN
# 2      shutter_5          3     camera_0  shutter  False      NaN
# 3           cw_5          3  turntable_0       cw      5      NaN
# 4     shutter_10          3     camera_0  shutter  False      NaN
# ..           ...        ...          ...      ...    ...      ...
# 141       cw_350          3  turntable_0       cw      5      NaN
# 142  shutter_355          3     camera_0  shutter  False      NaN
# 143       cw_355          3  turntable_0       cw      5      NaN
# 144  shutter_360          3     camera_0  shutter  False      NaN
# 145       cw_360          3  turntable_0       cw      5      NaN
#
# [146 rows x 6 columns]

# %% [markdown]
# If the tasks csv file is correct, run `UgokuKun.run()`.

# %%
session.run()
# Out:
# Executing task id: shutter_0 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_0 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_5 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_5 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_10 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_10 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_15 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_15 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_20 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_20 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_25 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_25 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_30 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_30 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_35 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_35 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_40 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_40 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_45 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_45 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_50 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_50 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_55 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_55 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_60 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_60 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_65 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_65 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_70 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_70 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_75 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_75 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_80 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_80 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_85 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_85 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_90 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_90 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_95 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_95 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_100 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_100 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_105 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_105 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_110 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_110 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_115 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_115 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_120 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_120 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_125 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_125 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_130 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_130 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_135 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_135 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_140 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_140 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_145 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_145 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_150 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_150 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_155 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_155 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_160 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_160 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_165 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_165 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_170 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_170 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_175 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_175 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_180 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_180 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_185 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_185 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_190 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_190 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_195 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_195 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_200 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_200 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_205 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_205 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_210 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_210 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_215 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_215 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_220 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_220 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_225 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_225 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_230 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_230 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_235 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_235 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_240 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_240 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_245 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_245 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_250 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_250 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_255 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_255 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_260 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_260 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_265 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_265 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_270 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_270 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_275 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_275 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_280 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_280 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_285 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_285 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_290 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_290 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_295 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_295 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_300 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_300 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_305 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_305 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_310 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_310 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_315 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_315 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_320 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_320 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_325 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_325 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_330 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_330 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_335 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_335 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_340 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_340 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_345 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_345 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_350 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_350 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_355 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_355 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.
# Executing task id: shutter_360 , action: shutter
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# Executing task id: cw_360 , action: cw
# Motor turned -5 degrees clockwise at 30 rpm.

# %% [markdown]
# ## TODO dump camera cofig
#
# Forgot to implement `CannonWrapper.dump_attribures()` in `UgokuKun`.

# %%
for camera_id in session.cannon_cameras.keys():
    session.cannon_instances[camera_id].dump_attributes(os.path.join(output_dir, f"{camera_id}.json"))
# Out:
#   - Settings dumped to: /home/ugoku/Dropbox (Danlab)/personal/naro-intern/ugoku-kun/readme_demo/dump/camera_0.json
