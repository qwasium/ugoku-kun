# %% [markdown]
# - Windows 10 22H2
# - Python 3.11.7

# %%
import os
from pprint import pprint

from tests.importers import JumpDir

with JumpDir(os.path.join('..', 'src'), os.getcwd()):
	__import__('ugoku_kun')
from ugoku_kun.cannon_wrapper import CannonWrapper

# %% [markdown]
# Connect to camera.

# %%
ip_address = '192.168.11.152'
# ip_address = '192.168.1.2'
port = '8080' # string
# uri = f'http://{ip_address}:{port}/ccapi'

remote = CannonWrapper(ip_port=ip_address + ':' + port)
# Out:
# API URL: http://192.168.11.152:8080/ccapi
#   - Request success: 200
#   - Connection established
# API URL: http://192.168.11.152:8080/ccapi/ver100/deviceinformation
#   - Request success: 200
#   - Acquired device information
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
# ...

# %% [markdown]
# Print all available api commands.

# %%
pprint(remote.api_url)
# pprint(remote.available_api)
# Out:
# ['http://192.168.11.152:8080/ccapi/ver100/deviceinformation',
#  'http://192.168.11.152:8080/ccapi/ver100/devicestatus/storage',
#  'http://192.168.11.152:8080/ccapi/ver100/devicestatus/battery',
#  'http://192.168.11.152:8080/ccapi/ver100/devicestatus/lens',
#  'http://192.168.11.152:8080/ccapi/ver100/devicestatus/temperature',
#  'http://192.168.11.152:8080/ccapi/ver100/functions/registeredname/copyright',
#  'http://192.168.11.152:8080/ccapi/ver100/functions/registeredname/author',
#  'http://192.168.11.152:8080/ccapi/ver100/functions/registeredname/ownername',
#  'http://192.168.11.152:8080/ccapi/ver100/functions/registeredname/nickname',
#  'http://192.168.11.152:8080/ccapi/ver100/functions/datetime',
#  'http://192.168.11.152:8080/ccapi/ver100/functions/cardformat',
#  'http://192.168.11.152:8080/ccapi/ver100/functions/beep',
#  'http://192.168.11.152:8080/ccapi/ver100/functions/displayoff',
#  'http://192.168.11.152:8080/ccapi/ver100/functions/autopoweroff',
# ...

# %% [markdown]
# Get shooting parameters.

# %%
remote.get_shooting_param()
remote.settings
# Out:
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
# ...

# %% [markdown]
# Set shooting parameters.

# %%
remote.set_aperture("f10")
# Out:
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/av
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
# ...

# %%
remote.set_exposure("-0_2/3")
# Out:
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/exposure
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
# ...

# %%
remote.set_iso("auto")
# Out:
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/iso
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
# ...

# %%
remote.set_color_temp(6000)
# Out:
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/colortemperature
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
# ...

# %%
remote.set_white_balance("auto")
# Out:
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/wb
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
# ...

# %%
remote.set_shutter_speed("5\"")
# Out:
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings/tv
#   - Request success: 200
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/settings
#   - Request success: 200
# ...

# %% [markdown]
# Press shutter button.

# %%
remote.shutter(False)
# Out:
# API URL: http://192.168.11.152:8080/ccapi/ver100/shooting/control/shutterbutton
#   - Request success: 200
#   - Shutter button pressed
# <Response [200]>

# %%
remote.dump_attributes(os.path.join("output", "control_cannon_dump.json"))
# Out:
#   - Settings dumped to: output/control_cannon_dump.json
# {'wait_time': 3,
#  'req_timeout': (3.0, 7.5),
#  'ip_port': '192.168.11.152:8080',
#  'max_attempts': 5,
#  'available_api': {'ver100': [{'url': 'http://192.168.11.152:8080/ccapi/ver100/deviceinformation',
#     'get': True,
#     'post': False,
#     'put': False,
#     'delete': False},
#    {'url': 'http://192.168.11.152:8080/ccapi/ver100/devicestatus/storage',
#     'get': True,
#     'post': False,
#     'put': False,
#     'delete': False},
#    {'url': 'http://192.168.11.152:8080/ccapi/ver100/devicestatus/battery',
#     'get': True,
#     'post': False,
#     'put': False,
#     'delete': False},
#    {'url': 'http://192.168.11.152:8080/ccapi/ver100/devicestatus/lens',
#     'get': True,
#     'post': False,
#     'put': False,
#     'delete': False},
#    {'url': 'http://192.168.11.152:8080/ccapi/ver100/devicestatus/temperature',
#     'get': True,
#     'post': False,
#     'put': False,
#     'delete': False},
# ...
